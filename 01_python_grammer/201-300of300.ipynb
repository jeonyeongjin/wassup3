# %% [markdown]
# 201. "비트코인" 문자열을 화면에 출력하는 print_coin() 함수를 정의하라.

# %%
def print_coin():
  print('비트코인')

# %% [markdown]
# 202. 201번에서 정의한 함수를 호출하라.

# %%
print_coin()
# Out:
# 비트코인

# %% [markdown]
# 203. 201번에서 정의한 print_coin 함수를 100번호출하라.

# %%
for index in range(100) :
  print_coin()
# Out:
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인

# %% [markdown]
# 204. "비트코인" 문자열을 100번 화면에 출력하는 print_coins() 함수를 정의하라

# %%
def  print_coins() :
  for index in range(100) :
    print_coin()

# %% [markdown]
# 205. 아래의 에러가 발생하는 이유에 대해 설명하라.
# ```
# hello()
# def hello():
#     print("Hi")
# ```
# 호출을 나중에 하기

# %% [markdown]
# 206. 아래 코드의 실행 결과를 예측하라.
# ```
#   def message() :
#       print("A")
#       print("B")
#
#   message()
#   print("C")
#   message()
#
#
#   A
#   B
#   C
#   A
#   B
# ```

# %% [markdown]
# 207. 아래 코드의 실행 결과를 예측하라. (읽기 어려운 코드의 예입니다.)
# ```
#   print("A")
#
#     def message() :
#       print("B")
#
#   print("C")
#   message()
# ```

# %% [markdown]
# a c b

# %% [markdown]
# 아래 코드의 실행 결과를 예측하라. (읽기 어려운 코드의 예입니다.)
# ```
#   print("A")
#   def message1() :
#       print("B")
#   print("C")
#   def message2() :
#       print("D")
#   message1()
#   print("E")
#   message2()
# ```

# %% [markdown]
# a c b e d

# %% [markdown]
# 209. 아래 코드의 실행 결과를 예측하라.
# ```
#   def message1():
#       print("A")
#
#   def message2():
#       print("B")
#      message1()
#
#   message2()
# ```

# %% [markdown]
# a b

# %% [markdown]
# 210. 아래 코드의 실행 결과를 예측하라.
# ```
#   def message1():
#       print("A")
#
#   def message2():
#       print("B")
#
#   def message3():
#        for i in range (3) :
#          message2()
#          print("C")
#        message1()
#
#   message3()
# ```

# %%
def message1():
 print("A")

def message2():
 print("B")

def message3():
  for i in range (3) :
    message2()
    print("C")
  message1()

message3()
# Out:
# B
# C
# B
# C
# B
# C
# A

# %% [markdown]
# 211. 함수의 호출 결과를 예측하라.
# ```
#   def 함수(문자열) :
#       print(문자열)
#
#   함수("안녕")
#   함수("Hi")
# ```

# %%
def 함수(문자열) :
 print(문자열)

함수("안녕")
함수("Hi")
# Out:
# 안녕
# Hi

# %% [markdown]
# 212. 함수의 호출 결과를 예측하라.
# ```
#   def 함수(a, b) :
#       print(a + b)
#
#   함수(3, 4)
#   함수(7, 8)
# ```

# %% [markdown]
# 7,
# 15

# %% [markdown]
# 213. 아래와 같은 에러가 발생하는 원인을 설명하라.
# ```
#   def 함수(문자열) :
#       print(문자열)
#   함수()
# ```
# 아귀먼트가 없음

# %%
def 함수(문자열) :
    print(문자열)
함수()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-2d48c99d5c2d> in <cell line: 3>()
#       1 def 함수(문자열) :
#       2     print(문자열)
# ----> 3 함수()
#
# TypeError: 함수() missing 1 required positional argument: '문자열'

# %% [markdown]
# 214. 아래와 같은 에러가 발생하는 원인을 설명하라.
# ```
#   def 함수(a, b) :
#       print(a + b)
#
#   함수("안녕", 3)
# ```
# 문자 + 숫자

# %% [markdown]
# 215. 하나의 문자를 입력받아 문자열 끝에 ":D" 스마일 문자열을 이어 붙여 출력하는 print_with_smile 함수를 정의하라.

# %%
text = input('하나의 문자를 입력하세요')
def print_with_smile(entry) :
  print(entry+":D")
# Out:
# 하나의 문자를 입력하세요안녕하세요

# %% [markdown]
# 216. 215에서 정의한 함수를 호출하라. 파라미터는 "안녕하세요"로 입력하라.

# %%
print_with_smile(text)
# Out:
# 안녕하세요:D

# %% [markdown]
# 217. 현재 가격을 입력 받아 상한가 (30%)를 출력하는 print_upper_price 함수를 정의하라.

# %%
nowprice = input('현재가격을 입력하세요')



def print_upper_price(upprice) :
  upprice = float(upprice) * 30/100+float(upprice)
  print(upprice)



print_upper_price(nowprice)
# Out:
# 현재가격을 입력하세요900
# 1170.0

# %% [markdown]
# 218. 두 개의 숫자를 입력받아 두 수의 합을 출력하는 print_sum 함수를 정의하라.

# %%
num1 = input('입력하세요')
num2 = input('입력하세요')

def print_sum(num1, num2) :

  print(int(num1) + int(num2))
print_sum(num1, num2)
# Out:
# 입력하세요5
# 입력하세요5
# 10

# %% [markdown]
# 219. 두 개의 숫자를 입력받아 합/차/곱/나눗셈을 출력하는 print_arithmetic_operation 함수를 작성하라.
# ```
# print_arithmetic_operation(3, 4)
# 3 + 4 = 7
# 3 - 4 = -1
# 3 * 4 = 12
# 3 / 4 = 0.75
# ```

# %%
num1 = input('입력하세요')
num2 = input('입력하세요')

def print_arithmetic_operation(num1, num2) :

  print(int(num1) + int(num2))
  print(int(num1) - int(num2))
  print(int(num1) * int(num2))
  print(int(num1) / int(num2))
print_arithmetic_operation(num1, num2)
# Out:
# 입력하세요5
# 입력하세요10
# 15
# -5
# 50
# 0.5

# %% [markdown]
# 220. 세 개의 숫자를 입력받아 가장 큰수를 출력하는 print_max 함수를 정의하라. 단 if 문을 사용해서 수를 비교하라.

# %%
num1 = input('입력하세요')
num2 = input('입력하세요')
num3 = input('입력하세요')


def print_max(num1, num2, num3) :

  if num1 > num2 :
     if num1 > num3 :
       print(num1)
     else :
      print(num3)
  else:#number2>number1
    if num2 > num3 :
      print(num2)
    else :
      print(num3)

print_max(num1, num2, num3)
# Out:
# 입력하세요10
# 입력하세요20
# 입력하세요30
# 30

# %% [markdown]
# 221. 입력된 문자열을 역순으로 출력하는 print_reverse 함수를 정의하라.
#
# print_reverse("python")

# %%
text = "python"

def print_reverse(text) :

  print(text[::-1])
print_reverse(text)
# Out:
# nohtyp

# %% [markdown]
# 222. 성적 리스트를 입력 받아 평균을 출력하는 print_score 함수를 정의하라.
# ```
#   print_score ([1, 2, 3])
#   2.0
# ```

# %%
score1 = input('성적입력하세요')
score2 = input('성적입력하세요')
score3 = input('성적입력하세요')

def print_score(score1, score2, score3) :
  avarage =( int(score1) + int(score2) + int(score3)) / 3
  print(avarage)
print_score (score1, score2, score3)
# Out:
# 성적입력하세요10
# 성적입력하세요303
# 성적입력하세요40
# 117.66666666666667

# %% [markdown]
# 223. 하나의 리스트를 입력받아 짝수만 화면에 출력하는 print_even 함수를 정의하라.
# ```
#   print_even ([1, 3, 2, 10, 12, 11, 15])
#   2
#   10
#   12
# ```

# %%
nums = [1, 3, 2, 10, 12, 11, 15]

def print_even(numlist) :
  for num in numlist :
    if num % 2 == 0 :
      print(num)

print_even(nums)
# Out:
# 2
# 10
# 12

# %% [markdown]
# 224. 하나의 딕셔너리를 입력받아 딕셔너리의 key 값을 화면에 출력하는 print_keys 함수를 정의하라.
# ```
#   print_keys ({"이름":"김말똥", "나이":30, "성별":0})
#   이름
#   나이
#   성별
# ```

# %%
name = input('이름을 입력하세요')
age = input('나이를 입력하세요')
sex = input('성별을 입력하세요')

def print_keys(name, age, sex) :
  print(name, age, sex)

print_keys(name, age, sex)
# Out:
# 이름을 입력하세요전영미
# 나이를 입력하세요30
# 성별을 입력하세요남
# 전영미 30 남

# %% [markdown]
# 225. my_dict에는 날짜를 키값으로 OHLC가 리스트로 저장돼 있다.
# ```
#   my_dict = {"10/26" : [100, 130, 100, 100],
#            "10/27" : [10, 12, 10, 11]}
#   my_dict와 날짜 키값을 입력받아 OHLC 리스트를 출력하는 print_value_by_key 함수를 정의하라.
#
#   print_value_by_key  (my_dict, "10/26")
#   [100, 130, 100, 100]
# ```

# %%
my_dict = {"10/26" : [100, 130, 100, 100],
           "10/27" : [10, 12, 10, 11]}


def print_value_by_key(my_dict, key) :

  print(my_dict[key])

print_value_by_key(my_dict, "10/27")
# Out:
# [10, 12, 10, 11]

# %% [markdown]
# 226. 입력 문자열을 한 줄에 다섯글자씩 출력하는 print_5xn(string) 함수를 작성하라.
# ```
#   print_5xn("아이엠어보이유알어걸")
#   아이엠어보
#   이유알어걸
# ```

# %%
def print_5xn(sentence) :
  for i in range(len(sentence)):
    if i%5==0:
      print(sentence[i:5+i])



print_5xn("아이엠어보이유알어걸ffkfkaalajflajgggg")
# Out:
# 아이엠어보
# 이유알어걸
# ffkfk
# aalaj
# flajg
# ggg

# %% [markdown]
# 227. 문자열과 한줄에 출력될 글자 수를 입력을 받아 한 줄에 입력된 글자 수만큼 출력하는 print_mxn(string) 함수를 작성하라.
# ```
#   printmxn("아이엠어보이유알어걸", 3)
#   아이엠
#   어보이
#   유알어
#   걸
# ```

# %%
def print_5xn(sentence) :
  for i in range(len(sentence)):
    if i%3==0:
      print(sentence[i:3+i])



print_5xn("아이엠어보이유알어걸")
# Out:
# 아이엠
# 어보이
# 유알어
# 걸

# %% [markdown]
# 228. 연봉을 입력받아 월급을 계산하는 calc_monthly_salary(annual_salary) 함수를 정의하라. 회사는 연봉을 12개월로 나누어 분할 지급하며, 이 때 1원 미만은 버림한다.
# ```
#   calc_monthly_salary(12000000)
#   1000000
# ```

# %%
def calc_monthly_salary(annual_salary) :
  month = annual_salary / 12
  print(int(month))


calc_monthly_salary(annual_salary=12000000)
# Out:
# 1000000

# %% [markdown]
# 229. 아래 코드의 실행 결과를 예측하라.
# ```
#   def my_print (a, b) :
#       print("왼쪽:", a)
#       print("오른쪽:", b)
#
#   my_print(a=100, b=200)
# ```

# %%
def my_print (a, b) :
 print("왼쪽:", a)
 print("오른쪽:", b)

my_print(a=100, b=200)
# Out:
# 왼쪽: 100
# 오른쪽: 200

# %% [markdown]
# 230. 아래 코드의 실행 결과를 예측하라.
# ```
#   def my_print (a, b) :
#       print("왼쪽:", a)
#       print("오른쪽:", b)
#
#   my_print(b=100, a=200)
# ```

# %%
def my_print (a, b) :
 print("왼쪽:", a)
 print("오른쪽:", b)

my_print(b=100, a=200)
# Out:
# 왼쪽: 200
# 오른쪽: 100

# %% [markdown]
# 231. 아래 코드를 실행한 결과를 예상하라.
# ```
#   def n_plus_1 (n) :
#       result = n + 1
#
#   n_plus_1(3)
#   print (result)
# ```

# %%
def n_plus_1 (n) :
    result = n + 1

n_plus_1(3)
print (result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-c23e796415bb> in <cell line: 5>()
#       3
#       4 n_plus_1(3)
# ----> 5 print (result)
#
# NameError: name 'result' is not defined

# %% [markdown]
# 232. 문자열 하나를 입력받아 인터넷 주소를 반환하는 make_url 함수를 정의하라.
# ```
# make_url("naver")
# www.naver.com
# ```

# %%
text = input('인터넷주소를 입력하세요')

def make_url(text) :
  print("www." + text + ".com")

make_url(text)
# Out:
# 인터넷주소를 입력하세요구글
# www.구글.com

# %% [markdown]
# 233. 문자열을 입력받아 각 문자들로 구성된 리스트로 반환하는 make_list 함수를 정의하라.
# ```
# make_list("abcd")
# ['a', 'b', 'c', 'd']
# ```

# %%
text = input('문자를 입력하세요')

def make_list(text) :
  empty_list = []

  for letter in text :
    empty_list.append(letter)

  print(empty_list)
make_list(text)
# Out:
# 문자를 입력하세요hello
# ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# 234. 숫자로 구성된 하나의 리스트를 입력받아, 짝수들을 추출하여 리스트로 반환하는 pickup_even 함수를 구현하라.
# ```
#   pickup_even([3, 4, 5, 6, 7, 8])
#   [4, 6, 8]
# ```

# %%
num = [3, 4, 5, 6, 7, 8]

def pickup_even(numlist) :

  emptylist = []
  for number in numlist :
    if number % 2 == 0 :
      emptylist.append(number)
  print(emptylist)


pickup_even(num)
# Out:
# [4, 6, 8]

# %% [markdown]
# 235. 콤마가 포함된 문자열 숫자를 입력받아 정수로 변환하는 convert_int 함수를 정의하라.
# ```
#   convert_int("1,234,567")
#   1234567
# ```

# %%
text = input("입력하세요")

def convert_int(number_string) :
  s_number=number_string.replace(',','')
  print(int(s_number))
convert_int(text)
# Out:
# 입력하세요1,2,3,4,5,6,7
# 1234567

# %% [markdown]
# 236. 아래 코드의 실행 결과를 예측하라.
# ```
#   def 함수(num) :
#       return num + 4
#
#   a = 함수(10)
#   b = 함수(a)
#   c = 함수(b)
#   print(c)
# ```

# %%
def 함수(num) :
  return num + 4

a = 함수(10)
b = 함수(a)
c = 함수(b)
print(c) #10+4+4+4
# Out:
# 22

# %% [markdown]
# 237. 아래 코드의 실행 결과를 예측하라.
# ```
#   def 함수(num) :
#      return num + 4
#
#   c = 함수(함수(함수(10)))
#   print(c)
# ```

# %%
def 함수(num) :
 return num + 4

c = 함수(함수(함수(10))) #10+4+4+4
print(c)
# Out:
# 22

# %% [markdown]
# 238. 아래 코드의 실행 결과를 예측하라.
# ```
#   def 함수1(num) :
#       return num + 4
#
#   def 함수2(num) :
#       return num * 10
#
#   a = 함수1(10)
#   c = 함수2(a)
#   print(c)
# ```

# %%
def 함수1(num) :
    return num + 4

def 함수2(num) :
    return num * 10

a = 함수1(10)#14
c = 함수2(a) #14 * 10
print(c)
# Out:
# 140

# %% [markdown]
# 239. 아래 코드의 실행 결과를 예측하라.
# ```
#   def 함수1(num) :
#       return num + 4
#
#   def 함수2(num) :
#       num = num + 2
#       return 함수1(num)
#
#   c = 함수2(10)
#   print(c)
# ```

# %%
def 함수1(num) :
  return num + 4

def 함수2(num) :
  num = num + 2 #12
  return 함수1(num)  #+4

c = 함수2(10)
print(c)
# Out:
# 16

# %% [markdown]
# 240. 아래 코드의 실행 결과를 예측하라.
# ```
#   def 함수0(num) :
#     return num * 2
#
#   def 함수1(num) :
#     return 함수0(num + 2)
#
#   def 함수2(num) :
#     num = num + 10
#     return 함수1(num)
#
#   c = 함수2(2)
#   print(c)
# ```

# %%
def 함수0(num) :
 return num * 2 #28

def 함수1(num) :
 return 함수0(num + 2) #14

def 함수2(num) :
  num = num + 10 #12
  return 함수1(num)

c = 함수2(2)
print(c)
# Out:
# 28

# %% [markdown]
# ### 파이썬 모듈

# %% [markdown]
# 241. 현재시간 - datetime 모듈을 사용해서 현재 시간을 화면에 출력해보세요.

# %%
import datetime

now = datetime.datetime.now()
print(now)
# Out:
# 2024-06-23 12:54:04.682035

# %% [markdown]
# 242. 현재시간의 타입 - datetime 모듈의 now 함수의 리턴 값의 타입을 화면에 출력해보세요.

# %%
import datetime

now = datetime.datetime.now()
print(now, type(now))
# Out:
# 2024-06-23 12:54:47.062710 <class 'datetime.datetime'>

# %% [markdown]
# 243. timedelta - datetime 모듈의 timedelta를 사용해서 오늘로부터 5일, 4일, 3일, 2일, 1일 전의 날짜를 화면에 출력해보세요.

# %%
import datetime

now = datetime.datetime.now()

for day in range(5, 0, -1):
  delta = datetime.timedelta(days=day)
  date = now - delta
  print(date)
# Out:
# 2024-06-18 12:55:27.872430
# 2024-06-19 12:55:27.872430
# 2024-06-20 12:55:27.872430
# 2024-06-21 12:55:27.872430
# 2024-06-22 12:55:27.872430

# %% [markdown]
# 244. strftime - 현재시간을 얻어온 후 다음과 같은 포맷으로 시간을 출력해보세요. strftime 메서드를 사용하세요.

# %%
import datetime

now = datetime.datetime.now()
print(now.strftime("%H:%M:%S"))
# Out:
# 12:56:02

# %% [markdown]
# 245. strptime
# datetime.datetime.strptime 메서드를 사용하면 문자열 형식의 시간을 datetime.datetime 타입의 시간 값으로 만들어줍니다. "2020-05-04"의 문자열을 시간 타입으로 변환해보세요.

# %%
import datetime

day = "2020-05-04"
ret = datetime.datetime.strptime(day, "%Y-%m-%d")
print(ret, type(ret))
# Out:
# 2020-05-04 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# 246. sleep 함수
# time 모듈, datetime 모듈을 사용해서 1초에 한 번 현재 시간을 출력하는 코드를 작성하세요.

# %%
import time
import datetime

while True:
  now = datetime.datetime.now()
  print(now)
  time.sleep(1)
# Out:
# 2024-06-23 12:56:52.790005
# 2024-06-23 12:56:53.792719
# 2024-06-23 12:56:54.793974
# 2024-06-23 12:56:55.794866
# 2024-06-23 12:56:56.796850
# 2024-06-23 12:56:57.798098
# 2024-06-23 12:56:58.799354
# 2024-06-23 12:56:59.800596
# 2024-06-23 12:57:00.801867
# 2024-06-23 12:57:01.803113
# 2024-06-23 12:57:02.804412
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-ff6a7c17cf1d> in <cell line: 4>()
#       5     now = datetime.datetime.now()
#       6     print(now)
# ----> 7     time.sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# 247. 모듈 임포트
# 모듈을 임포트하는 4가지 방식에 대해 설명해보세요.

# %% [markdown]
# 248. os 모듈
# os 모듈의 getcwd 함수를 호출하여 현재 디렉터리의 경로를 화면에 출력해보세요.

# %%
import os
ret = os.getcwd()
print(ret, type(ret))
# Out:
# /content <class 'str'>

# %% [markdown]
# 249. rename 함수
# 바탕화면에 텍스트 파일을 하나 생성한 후 os 모듈의 rename 함수를 호출하여 해당 파일의 이름을 변경해보세요.

# %%
import os
os.rename("C:/Users/yeongjinjeon/Desktop/01.txt", "C:/Users/yeongjinjeon/Desktop/02.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-ccabb1e3964e> in <cell line: 2>()
#       1 import os
# ----> 2 os.rename("C:/Users/yeongjinjeon/Desktop/01.txt", "C:/Users/yeongjinjeon/Desktop/02.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/yeongjinjeon/Desktop/01.txt' -> 'C:/Users/yeongjinjeon/Desktop/02.txt'

# %% [markdown]
# 250. numpy - numpy 모듈의 arange 함수를 사용해서 0.0 부터 5.0까지 0.1씩 증가하는 값을 화면에 출력해보세요.

# %%
import numpy as np
for num in np.arange(0, 5, 0.1) :
  print(num)
# Out:
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4
# 0.5
# 0.6000000000000001
# 0.7000000000000001
# 0.8
# 0.9
# 1.0
# 1.1
# 1.2000000000000002
# 1.3
# 1.4000000000000001
# 1.5
# 1.6
# 1.7000000000000002
# 1.8
# 1.9000000000000001
# 2.0
# 2.1
# 2.2
# 2.3000000000000003
# 2.4000000000000004
# 2.5
# 2.6
# 2.7
# 2.8000000000000003
# 2.9000000000000004
# 3.0
# 3.1
# 3.2
# 3.3000000000000003
# 3.4000000000000004
# 3.5
# 3.6
# 3.7
# 3.8000000000000003
# 3.9000000000000004
# 4.0
# 4.1000000000000005
# 4.2
# 4.3
# 4.4
# 4.5
# 4.6000000000000005
# 4.7
# 4.800000000000001
# 4.9
